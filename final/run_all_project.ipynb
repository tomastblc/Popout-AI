# %% [markdown]
# # PopOut AI: unified workflow
#
# Р­С‚РѕС‚ notebook Р·Р°РїСѓСЃРєР°РµС‚ РѕРґРёРЅ РЅРµРїСЂРµСЂС‹РІРЅС‹Р№ workflow РїСЂРѕРµРєС‚Р°:
#
# 1. РґРµРјРѕРЅСЃС‚СЂР°С†РёСЏ Р»РѕРіРёРєРё РґРѕСЃРєРё;
# 2. РіРµРЅРµСЂР°С†РёСЏ self-play dataset Рё РѕР±СѓС‡РµРЅРёРµ ID3;
# 3. cross-validation РЅР° Iris;
# 4. СЃСЂР°РІРЅРµРЅРёРµ СЂР°Р·РЅС‹С… СЂРµР¶РёРјРѕРІ MCTS;
# 5. РіРµРЅРµСЂР°С†РёСЏ С‚СѓСЂРЅРёСЂРЅРѕРіРѕ dataset;
# 6. РјР°С‚С‡Рё `ID3 vs MCTS`.
#
# РџР°СЂР°РјРµС‚СЂС‹ РїРѕ СѓРјРѕР»С‡Р°РЅРёСЋ СЃРґРµР»Р°РЅС‹ РєРѕРјРїР°РєС‚РЅС‹РјРё, С‡С‚РѕР±С‹ `Run All` РІС‹РїРѕР»РЅСЏР»СЃСЏ Р±РµР· СЂСѓС‡РЅРѕРіРѕ РІРІРѕРґР°.

# %%
from pathlib import Path
import os

NOTEBOOK_DIR = Path.cwd()
if not (NOTEBOOK_DIR / 'workflow_support.py').exists():
    candidates = [Path.cwd(), Path.cwd() / 'final']
    for candidate in candidates:
        if (candidate / 'workflow_support.py').exists():
            os.chdir(candidate)
            NOTEBOOK_DIR = candidate
            break

from workflow_support import (
    FILES_DIR,
    board_demo,
    ensure_local_paths,
    evaluate_id3_against_specs,
    generate_selfplay_dataset,
    generate_tournament_dataset,
    iris_workflow,
    round_robin_workflow,
    specs_to_frame,
    train_popout_tree_from_csv,
    workflow_specs,
)

ROOT, FILES_DIR = ensure_local_paths()
print(f'Working directory: {ROOT}')
print(f'Files directory: {FILES_DIR}')
# Out:
# Working directory: D:\FCUP\2_year\IntArt\Popout-AI\final
# Files directory: D:\FCUP\2_year\IntArt\Popout-AI\final\files

# %%
SELFPLAY_GAMES = 6
SELFPLAY_ITERATIONS = 80
MCTS_ITERATIONS = 120
ROUND_ROBIN_GAMES_PER_SIDE = 1
TOURNAMENT_GAMES_PER_SIDE = 1
ID3_VS_MCTS_GAMES_PER_SIDE = 2

SELFPLAY_DATASET = FILES_DIR / 'popout_workflow_dataset.csv'
SELFPLAY_TREE = FILES_DIR / 'popout_workflow_tree.json'
TOURNAMENT_DATASET = FILES_DIR / 'popout_tournament_workflow.csv'
TOURNAMENT_TREE = FILES_DIR / 'popout_tournament_tree.json'

# %% [markdown]
# ## 1. Board demo

# %%
final_state, board_demo_df = board_demo()
for row in board_demo_df.itertuples(index=False):
    print(f'=== Step {row.step}: {row.move} ===')
    print(row.board)
    print()

board_demo_df[['step', 'move', 'winner']]
# Out:
# === Step 0: initial ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# 0 1 2 3 4 5 6
# player_to_move=X
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6']
#
# === Step 1: drop_0 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# X - - - - - -
# 0 1 2 3 4 5 6
# player_to_move=O
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6']
#
# === Step 2: drop_1 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# X O - - - - -
# 0 1 2 3 4 5 6
# player_to_move=X
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6', 'pop_0']
#
# === Step 3: drop_0 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# X - - - - - -
# X O - - - - -
# 0 1 2 3 4 5 6
# player_to_move=O
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6', 'pop_1']
#
# === Step 4: drop_1 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# X O - - - - -
# X O - - - - -
# 0 1 2 3 4 5 6
# player_to_move=X
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6', 'pop_0']
#
# === Step 5: pop_0 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - O - - - - -
# X O - - - - -
# 0 1 2 3 4 5 6
# player_to_move=O
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6', 'pop_1']
#
# === Step 6: drop_2 ===
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - O - - - - -
# X O O - - - -
# 0 1 2 3 4 5 6
# player_to_move=X
# legal_moves=['drop_0', 'drop_1', 'drop_2', 'drop_3', 'drop_4', 'drop_5', 'drop_6', 'pop_0']
#    step     move winner
# 0     0  initial   None
# 1     1   drop_0   None
# 2     2   drop_1   None
# 3     3   drop_0   None
# 4     4   drop_1   None
# 5     5    pop_0   None
# 6     6   drop_2   None

# %% [markdown]
# ## 2. Self-play dataset + ID3 training

# %%
selfplay_rows = generate_selfplay_dataset(
    SELFPLAY_DATASET,
    num_games=SELFPLAY_GAMES,
    iterations=SELFPLAY_ITERATIONS,
)
print(f'Self-play rows: {len(selfplay_rows)}')

popout_tree_info = train_popout_tree_from_csv(SELFPLAY_DATASET, SELFPLAY_TREE)
popout_tree_info
# Out:
# A gerar 6 jogos para o dataset...
# A usar 1 processo.
# Dataset guardado com sucesso em 'D:\FCUP\2_year\IntArt\Popout-AI\final\files\popout_workflow_dataset.csv' com 77 linhas!
# Self-play rows: 77
# {'tree': {'c1_r2': {'X': {'c3_r4': {'X': 'pop_4',
#      'Vazio': {'player_to_move': {'X': {'c2_r1': {'Vazio': 'drop_0',
#          'O': 'drop_3'}},
#        'O': {'c3_r3': {'X': 'drop_4',
#          'Vazio': {'c3_r2': {'Vazio': 'drop_3', 'O': 'drop_2'}}}}}}}},
#    'Vazio': {'c6_r0': {'X': {'player_to_move': {'X': 'drop_0',
#        'O': {'c2_r0': {'Vazio': 'drop_2', 'O': 'drop_4'}}}},
#      'Vazio': {'c3_r1': {'X': {'player_to_move': {'X': {'c5_r2': {'Vazio': 'drop_2',
#            'O': 'drop_0'}},
#          'O': 'drop_5'}},
#        'Vazio': {'c3_r0': {'X': {'c4_r0': {'X': {'c5_r0': {'X': 'drop_6',
#              'Vazio': 'drop_5',
#              'O': 'drop_3'}},
#            'Vazio': {'player_to_move': {'X': {'c2_r0': {'X': 'drop_4',
#                'Vazio': 'drop_2'}},
#              'O': {'c2_r0': {'X': 'drop_1',
#                'Vazio': {'repetition_count': {0: {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c5_r0': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_4'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#            'O': {'player_to_move': {'X': 'drop_1', 'O': 'drop_3'}}}},
#          'Vazio': {'c0_r0': {'X': {'c0_r2': {'X': {'c5_r1': {'X': 'drop_3',
#                'Vazio': 'drop_5'}},
#              'Vazio': 'drop_0'}},
#            'Vazio': {'c4_r0': {'X': {'player_to_move': {'X': {'c5_r0': {'X': 'drop_3',
#                  'Vazio': 'drop_5'}},
#                'O': 'drop_4'}},
#              'Vazio': {'player_to_move': {'X': {'repetition_count': {0: {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c5_r0': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': 'drop_3'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#                'O': 'drop_3'}}}}}},
#          'O': {'c5_r0': {'X': 'drop_3', 'Vazio': 'drop_5', 'O': 'drop_6'}}}},
#        'O': {'c4_r0': {'X': {'c2_r0': {'X': {'player_to_move': {'X': {'c2_r1': {'Vazio': 'drop_0',
#                'O': 'drop_4'}},
#              'O': {'c3_r3': {'Vazio': 'drop_3', 'O': 'drop_2'}}}},
#            'Vazio': {'player_to_move': {'X': 'drop_2',
#              'O': {'c5_r2': {'Vazio': 'drop_2', 'O': 'drop_1'}}}},
#            'O': {'player_to_move': {'X': 'drop_3', 'O': 'drop_6'}}}},
#          'Vazio': {'c0_r0': {'Vazio': {'player_to_move': {'X': {'c5_r0': {'X': 'drop_3',
#                'Vazio': 'drop_4'}},
#              'O': 'drop_0'}},
#            'O': {'c5_r2': {'Vazio': 'drop_5', 'O': 'drop_4'}}}},
#          'O': {'c4_r1': {'X': 'drop_1',
#            'Vazio': {'player_to_move': {'X': {'c2_r0': {'X': 'drop_4',
#                'Vazio': 'drop_2'}},
#              'O': 'drop_0'}}}}}}}},
#      'O': {'player_to_move': {'X': {'c3_r1': {'X': {'c3_r2': {'X': 'drop_5',
#            'Vazio': {'c2_r1': {'Vazio': 'drop_0', 'O': 'drop_3'}}}},
#          'Vazio': 'drop_2',
#          'O': 'pop_3'}},
#        'O': {'c3_r2': {'X': 'drop_1',
#          'Vazio': {'c1_r0': {'Vazio': 'drop_1', 'O': 'drop_2'}}}}}}}},
#    'O': {'player_to_move': {'X': 'pop_0', 'O': 'drop_0'}}}},
#  'dataset_path': 'D:\\FCUP\\2_year\\IntArt\\Popout-AI\\final\\files\\popout_workflow_dataset.csv',
#  'tree_path': 'D:\\FCUP\\2_year\\IntArt\\Popout-AI\\final\\files\\popout_workflow_tree.json',
#  'rows': 77,
#  'attributes': 45,
#  'nodes': 185,
#  'depth': 45}

# %% [markdown]
# ## 3. Iris cross-validation

# %%
iris_results_df = iris_workflow(csv_path='files/iris.csv', k=5, num_bins=4, seed=42)
iris_results_df
# Out:
# Fold 1/5: accuracy=0.867, unknown_rate=0.033, tree=arvore_iris_fold_1.json
# Fold 2/5: accuracy=0.900, unknown_rate=0.067, tree=arvore_iris_fold_2.json
# Fold 3/5: accuracy=0.933, unknown_rate=0.000, tree=arvore_iris_fold_3.json
# Fold 4/5: accuracy=0.933, unknown_rate=0.000, tree=arvore_iris_fold_4.json
# Fold 5/5: accuracy=0.867, unknown_rate=0.067, tree=arvore_iris_fold_5.json
#
# Resumo:
# Accuracy media: 0.900
# Unknown rate medio: 0.033
#    fold  accuracy  unknown_rate  \
# 0     1  0.866667      0.033333
# 1     2  0.900000      0.066667
# 2     3  0.933333      0.000000
# 3     4  0.933333      0.000000
# 4     5  0.866667      0.066667
#
#                                            tree_path
# 0  D:\FCUP\2_year\IntArt\Popout-AI\final\artifact...
# 1  D:\FCUP\2_year\IntArt\Popout-AI\final\artifact...
# 2  D:\FCUP\2_year\IntArt\Popout-AI\final\artifact...
# 3  D:\FCUP\2_year\IntArt\Popout-AI\final\artifact...
# 4  D:\FCUP\2_year\IntArt\Popout-AI\final\artifact...

# %% [markdown]
# ## 4. MCTS modes

# %%
specs = workflow_specs(iterations=MCTS_ITERATIONS)
specs_to_frame(specs)
# Out:
#                         name  kind  iterations  exploration_c  \
# 0               UCT_base_120  mcts         120          1.414
# 1              UCT_low_c_120  mcts         120          0.700
# 2  UCT_heuristic_rollout_120  mcts         120          1.414
# 3     UCT_epsilon_greedy_120  mcts         120          1.414
#
#   expansion_policy  expansion_k  rollout_policy rollout_depth_limit  \
# 0              all            0          random                None
# 1              all            0          random                None
# 2              all            0       heuristic                None
# 3              all            0  epsilon_greedy                None
#
#   child_selection  draw_value  epsilon
# 0             uct         0.5     0.10
# 1             uct         0.5     0.10
# 2             uct         0.5     0.10
# 3             uct         0.5     0.15

# %%
round_robin_summary, round_robin_ranking_df, round_robin_matches_df = round_robin_workflow(
    specs,
    games_per_side=ROUND_ROBIN_GAMES_PER_SIDE,
    num_workers=1,
)

round_robin_ranking_df
# Out:
# UCT_base_120 vs UCT_low_c_120: 0.0 - 2.0, draws=0, avg_moves=21.5, avg_move_time=(UCT_base_120: 0.0729s, UCT_low_c_120: 0.0656s)
# UCT_base_120 vs UCT_heuristic_rollout_120: 1.0 - 1.0, draws=0, avg_moves=14.0, avg_move_time=(UCT_base_120: 0.0820s, UCT_heuristic_rollout_120: 0.3980s)
# UCT_base_120 vs UCT_epsilon_greedy_120: 0.0 - 2.0, draws=0, avg_moves=12.5, avg_move_time=(UCT_base_120: 0.0894s, UCT_epsilon_greedy_120: 0.3196s)
# UCT_low_c_120 vs UCT_heuristic_rollout_120: 1.0 - 1.0, draws=0, avg_moves=8.0, avg_move_time=(UCT_low_c_120: 0.0872s, UCT_heuristic_rollout_120: 0.4411s)
# UCT_low_c_120 vs UCT_epsilon_greedy_120: 0.0 - 2.0, draws=0, avg_moves=8.5, avg_move_time=(UCT_low_c_120: 0.0965s, UCT_epsilon_greedy_120: 0.3830s)
# UCT_heuristic_rollout_120 vs UCT_epsilon_greedy_120: 0.0 - 2.0, draws=0, avg_moves=10.5, avg_move_time=(UCT_heuristic_rollout_120: 0.4141s, UCT_epsilon_greedy_120: 0.3406s)
#                        agent  score
# 0     UCT_epsilon_greedy_120    6.0
# 1              UCT_low_c_120    3.0
# 2  UCT_heuristic_rollout_120    2.0
# 3               UCT_base_120    1.0

# %%
round_robin_matches_df
# Out:
#                      agent_a                    agent_b  score_a  score_b  \
# 0               UCT_base_120              UCT_low_c_120      0.0      2.0
# 1               UCT_base_120  UCT_heuristic_rollout_120      1.0      1.0
# 2               UCT_base_120     UCT_epsilon_greedy_120      0.0      2.0
# 3              UCT_low_c_120  UCT_heuristic_rollout_120      1.0      1.0
# 4              UCT_low_c_120     UCT_epsilon_greedy_120      0.0      2.0
# 5  UCT_heuristic_rollout_120     UCT_epsilon_greedy_120      0.0      2.0
#
#    draws  games  avg_moves  avg_move_time_a  avg_move_time_b
# 0      0      2       21.5         0.072887         0.065570
# 1      0      2       14.0         0.081988         0.398040
# 2      0      2       12.5         0.089405         0.319556
# 3      0      2        8.0         0.087204         0.441125
# 4      0      2        8.5         0.096461         0.383013
# 5      0      2       10.5         0.414109         0.340647

# %% [markdown]
# ## 5. Tournament dataset + tournament-trained ID3

# %%
tournament_rows = generate_tournament_dataset(
    TOURNAMENT_DATASET,
    specs,
    games_per_side=TOURNAMENT_GAMES_PER_SIDE,
)
print(f'Tournament rows: {len(tournament_rows)}')

tournament_tree_info = train_popout_tree_from_csv(TOURNAMENT_DATASET, TOURNAMENT_TREE)
tournament_tree_info
# Out:
# A correr torneio 1/1: workflow_tournament com 4 agentes.
# Dataset guardado com sucesso em 'D:\FCUP\2_year\IntArt\Popout-AI\final\files\popout_tournament_workflow.csv' com 140 linhas!
# Tournament rows: 140
# {'tree': {'c3_r1': {'X': {'c4_r1': {'X': {'player_to_move': {'X': {'c6_r0': {'Vazio': 'drop_0',
#          'O': {'c2_r1': {'X': 'drop_1', 'Vazio': 'drop_2'}}}},
#        'O': {'c6_r0': {'Vazio': {'c1_r0': {'Vazio': 'drop_1', 'O': 'pop_3'}},
#          'O': {'c5_r1': {'Vazio': 'drop_5', 'O': 'drop_0'}}}}}},
#      'Vazio': {'c6_r0': {'X': {'c3_r4': {'Vazio': {'c5_r0': {'Vazio': {'player_to_move': {'X': 'drop_3',
#              'O': {'c3_r3': {'X': 'drop_3', 'Vazio': 'drop_1'}}}},
#            'O': 'pop_5'}},
#          'O': {'c6_r1': {'X': {'c1_r3': {'X': 'drop_4', 'Vazio': 'drop_1'}},
#            'Vazio': 'drop_6'}}}},
#        'Vazio': {'c5_r1': {'X': {'c2_r0': {'X': 'drop_6',
#            'Vazio': {'player_to_move': {'X': 'drop_2', 'O': 'drop_4'}},
#            'O': 'drop_6'}},
#          'Vazio': {'player_to_move': {'X': {'c4_r0': {'X': 'drop_4',
#              'Vazio': 'drop_5'}},
#            'O': {'c0_r0': {'X': 'drop_5', 'Vazio': 'drop_2'}}}},
#          'O': 'drop_6'}},
#        'O': {'c3_r2': {'X': {'c5_r5': {'Vazio': {'player_to_move': {'X': 'drop_5',
#              'O': {'c6_r1': {'Vazio': {'c5_r4': {'Vazio': 'drop_6',
#                  'O': 'drop_5'}},
#                'O': 'drop_2'}}}},
#            'O': 'drop_4'}},
#          'Vazio': {'player_to_move': {'X': {'c1_r0': {'X': 'drop_3',
#              'Vazio': 'drop_1'}},
#            'O': 'drop_5'}}}}}},
#      'O': {'player_to_move': {'X': 'drop_2', 'O': 'drop_6'}}}},
#    'Vazio': {'c4_r0': {'X': {'c5_r0': {'X': {'player_to_move': {'X': 'drop_3',
#          'O': 'drop_6'}},
#        'Vazio': {'c3_r0': {'X': 'drop_5',
#          'Vazio': {'repetition_count': {0: {'player_to_move': {'O': {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_5'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#          'O': 'drop_3'}},
#        'O': {'c6_r0': {'X': {'player_to_move': {'X': {'c2_r0': {'X': 'drop_3',
#              'Vazio': 'drop_2'}},
#            'O': {'c3_r0': {'Vazio': 'drop_3', 'O': 'drop_1'}}}},
#          'Vazio': 'drop_6'}}}},
#      'Vazio': {'c5_r0': {'X': {'c3_r0': {'X': {'c6_r0': {'Vazio': 'drop_3',
#            'O': 'drop_4'}},
#          'Vazio': {'c5_r3': {'Vazio': {'c5_r1': {'Vazio': {'repetition_count': {0: {'player_to_move': {'O': {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r2': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_5'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#              'O': 'drop_5'}},
#            'O': {'player_to_move': {'X': 'drop_2', 'O': 'drop_3'}}}},
#          'O': {'c2_r3': {'X': 'drop_4', 'Vazio': 'drop_2'}}}},
#        'Vazio': {'c3_r0': {'X': {'player_to_move': {'X': 'drop_5',
#            'O': {'c2_r1': {'Vazio': {'repetition_count': {0: {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_0'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#              'O': 'drop_3'}}}},
#          'Vazio': {'player_to_move': {'X': {'c2_r1': {'Vazio': {'repetition_count': {0: {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c1_r0': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_3'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#              'O': 'drop_3'}},
#            'O': {'c2_r0': {'X': 'drop_2',
#              'Vazio': {'c1_r0': {'X': {'repetition_count': {0: {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'Vazio': 'drop_3'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#                'Vazio': 'drop_3'}}}}}},
#          'O': {'c1_r0': {'X': 'drop_3',
#            'Vazio': {'repetition_count': {0: {'player_to_move': {'X': {'draw_legal': {False: {'c6_r5': {'Vazio': {'c6_r4': {'Vazio': {'c6_r3': {'Vazio': {'c6_r2': {'Vazio': {'c6_r1': {'Vazio': {'c6_r0': {'Vazio': {'c5_r5': {'Vazio': {'c5_r4': {'Vazio': {'c5_r3': {'Vazio': {'c5_r2': {'Vazio': {'c5_r1': {'Vazio': {'c4_r5': {'Vazio': {'c4_r4': {'Vazio': {'c4_r3': {'Vazio': {'c4_r2': {'Vazio': {'c4_r1': {'Vazio': {'c3_r5': {'Vazio': {'c3_r4': {'Vazio': {'c3_r3': {'Vazio': {'c3_r2': {'Vazio': {'c2_r5': {'Vazio': {'c2_r4': {'Vazio': {'c2_r3': {'Vazio': {'c2_r2': {'Vazio': {'c2_r1': {'Vazio': {'c2_r0': {'Vazio': {'c1_r5': {'Vazio': {'c1_r4': {'Vazio': {'c1_r3': {'Vazio': {'c1_r2': {'Vazio': {'c1_r1': {'Vazio': {'c0_r5': {'Vazio': {'c0_r4': {'Vazio': {'c0_r3': {'Vazio': {'c0_r2': {'Vazio': {'c0_r1': {'Vazio': {'c0_r0': {'X': 'drop_1'}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}}},
#        'O': {'player_to_move': {'X': {'c3_r0': {'X': 'drop_2',
#            'Vazio': 'drop_3'}},
#          'O': {'c2_r0': {'X': 'drop_4', 'Vazio': 'drop_1'}}}}}},
#      'O': {'c1_r0': {'X': {'player_to_move': {'X': {'c2_r0': {'X': 'drop_0',
#            'Vazio': 'drop_2'}},
#          'O': 'drop_6'}},
#        'Vazio': {'c3_r0': {'X': {'c4_r2': {'Vazio': 'drop_4', 'O': 'drop_1'}},
#          'Vazio': {'player_to_move': {'X': {'c6_r0': {'Vazio': 'drop_4',
#              'O': 'drop_0'}},
#            'O': {'c6_r0': {'Vazio': 'drop_6', 'O': 'drop_3'}}}},
#          'O': {'c5_r1': {'X': 'drop_1',
#            'Vazio': 'drop_5',
#            'O': {'player_to_move': {'X': 'drop_4', 'O': 'pop_4'}}}}}},
#        'O': {'player_to_move': {'X': 'drop_5', 'O': 'drop_2'}}}}}},
#    'O': {'c2_r1': {'X': {'player_to_move': {'X': {'c0_r3': {'Vazio': 'drop_0',
#          'O': {'c5_r0': {'X': 'drop_4', 'Vazio': 'drop_5'}}}},
#        'O': {'c1_r2': {'Vazio': {'c2_r2': {'Vazio': {'c1_r1': {'Vazio': 'drop_1',
#              'O': 'drop_2'}},
#            'O': 'drop_1'}},
#          'O': {'c5_r0': {'X': {'c4_r0': {'X': 'drop_0', 'Vazio': 'drop_1'}},
#            'Vazio': 'drop_0'}}}}}},
#      'Vazio': {'c0_r0': {'X': 'pop_0',
#        'Vazio': {'player_to_move': {'X': {'c2_r0': {'Vazio': 'drop_1',
#            'O': 'drop_2'}},
#          'O': {'c3_r0': {'X': 'drop_2', 'O': 'drop_3'}}}},
#        'O': {'player_to_move': {'X': {'c4_r0': {'X': 'drop_2',
#            'Vazio': 'drop_4'}},
#          'O': 'drop_3'}}}},
#      'O': {'player_to_move': {'X': {'c4_r0': {'X': 'drop_5',
#          'Vazio': 'drop_4'}},
#        'O': 'drop_1'}}}}}},
#  'dataset_path': 'D:\\FCUP\\2_year\\IntArt\\Popout-AI\\final\\files\\popout_tournament_workflow.csv',
#  'tree_path': 'D:\\FCUP\\2_year\\IntArt\\Popout-AI\\final\\files\\popout_tournament_tree.json',
#  'rows': 140,
#  'attributes': 45,
#  'nodes': 419,
#  'depth': 45}

# %% [markdown]
# ## 6. ID3 vs MCTS matches

# %%
id3_summary_df, id3_games_df = evaluate_id3_against_specs(
    tournament_tree_info['tree'],
    specs,
    games_per_side=ID3_VS_MCTS_GAMES_PER_SIDE,
    fallback_iterations=60,
)
id3_summary_df
# Out:
#                     opponent  games  id3_score  mcts_score  draws
# 0               UCT_base_120      4        0.0         4.0      0
# 1              UCT_low_c_120      4        1.0         3.0      0
# 2  UCT_heuristic_rollout_120      4        1.0         3.0      0
# 3     UCT_epsilon_greedy_120      4        1.0         3.0      0

# %%
id3_games_df
# Out:
#     game id3_side mcts_side                     winner  moves  \
# 0      1        X         O               UCT_base_120     12
# 1      2        X         O               UCT_base_120     16
# 2      3        O         X               UCT_base_120     15
# 3      4        O         X               UCT_base_120     19
# 4      1        X         O              UCT_low_c_120     14
# 5      2        X         O                        ID3      9
# 6      3        O         X              UCT_low_c_120     11
# 7      4        O         X              UCT_low_c_120     11
# 8      1        X         O                        ID3     13
# 9      2        X         O  UCT_heuristic_rollout_120     18
# 10     3        O         X  UCT_heuristic_rollout_120      7
# 11     4        O         X  UCT_heuristic_rollout_120     11
# 12     1        X         O     UCT_epsilon_greedy_120     16
# 13     2        X         O                        ID3      7
# 14     3        O         X     UCT_epsilon_greedy_120     15
# 15     4        O         X     UCT_epsilon_greedy_120      7
#
#                      opponent
# 0                UCT_base_120
# 1                UCT_base_120
# 2                UCT_base_120
# 3                UCT_base_120
# 4               UCT_low_c_120
# 5               UCT_low_c_120
# 6               UCT_low_c_120
# 7               UCT_low_c_120
# 8   UCT_heuristic_rollout_120
# 9   UCT_heuristic_rollout_120
# 10  UCT_heuristic_rollout_120
# 11  UCT_heuristic_rollout_120
# 12     UCT_epsilon_greedy_120
# 13     UCT_epsilon_greedy_120
# 14     UCT_epsilon_greedy_120
# 15     UCT_epsilon_greedy_120

# %% [markdown]
# ## 7. Output files
#
# РџРѕСЃР»Рµ `Run All` РѕСЃРЅРѕРІРЅС‹Рµ Р°СЂС‚РµС„Р°РєС‚С‹ Р»РµР¶Р°С‚ РІ `final/files/`.

# %%
sorted(path.name for path in FILES_DIR.iterdir())
# Out:
# ['arvore_iris_fold_1.json',
#  'arvore_iris_fold_2.json',
#  'arvore_iris_fold_3.json',
#  'arvore_iris_fold_4.json',
#  'arvore_iris_fold_5.json',
#  'popout_tournament_tree.json',
#  'popout_tournament_workflow.csv',
#  'popout_workflow_dataset.csv',
#  'popout_workflow_tree.json']
